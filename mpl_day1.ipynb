# %% [markdown]
# DAY 1 - MATPLOTLIB BASICS & PYPLOT INTERFACE

# %% [markdown]
# INSTALLATION

# %%
# %pip install matplotlib

# %% [markdown]
# IMPORT LIBRARY

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# DEMO 1

# %%
days = [1, 2, 3]
money_saved = [6000, 4000, 2000] # dollars

plt.plot(days, money_saved)

plt.show()

# %% [markdown]
# DEMO 2

# %%
hours = [0, 1, 2, 3]
phone_charge = [0, 10, 40, 90] # percentage

plt.plot(hours, phone_charge)

plt.show()

# %% [markdown]
# SOLO CHALLENGE

# %%
days = [1, 2, 3, 4, 5]
steps = [3000, 4500, 5000, 6500, 8000]

# draw a line
plt.plot(days, steps)

# show the image
plt.show()

# %% [markdown]
# CHEAT SHEET CONCEPTS

# %% [raw]
# Think of Matplotlib like drawing on paper:
#
# Figure = the paper
#
# Axes = the drawing area on the paper
#
# pyplot (plt) = the pencil
#
# plot() = draw a line
#
# show() = show the drawing

# %% [markdown]
# HOMEWORK

# %% [raw]
# Write a script that:
#
# Plots any 2 lists
#
# Runs without error
#
# Shows a line
